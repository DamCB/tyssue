# %%
import matplotlib.pyplot as plt
# %matplotlib inline

from tyssue import config
from tyssue.draw.plt_draw import sheet_view, quick_edge_draw

# %% [markdown]
# ## Planar Geometries
#
# It's simple to create hexagonal apical junction meshes with the `Sheet` class method `plaanr_sheet_2d()`:

# %%
from tyssue.core.sheet import Sheet
from tyssue.geometry.sheet_geometry import PlanarGeometry

sheet_2d = Sheet.planar_sheet_2d('planar', nx=6, ny=6, 
                                 distx=1, disty=1)
PlanarGeometry.update_all(sheet_2d)

# %%
fig, ax = sheet_view(sheet_2d)

# %%
import pandas as pd
import numpy as np

# %%
fig, ax = plt.subplots()
quick_edge_draw(sheet_2d, ["x", "y"], ax, c='k')

# %% [markdown]
# ## Sheet geometry in 3D

# %%
from tyssue.geometry.sheet_geometry import SheetGeometry

sheet_3d = Sheet.planar_sheet_3d('sheet', nx=6, ny=6, 
                                 distx=1, disty=1)
SheetGeometry.update_all(sheet_3d)

# %%
sheet_3d.vert_df.head()
# Out:
#           y     x is_active  z  rho  height  basal_shift
# vert
# 0     2.000 -0.75      True  0    0    -4.0          4.0
# 1     2.625  0.50      True  0    0    -4.0          4.0
# 2     3.375  1.50      True  0    0    -4.0          4.0
# 3     2.625  2.50      True  0    0    -4.0          4.0
# 4     3.375  0.50      True  0    0    -4.0          4.0

# %%
fig, ax = plt.subplots()
quick_edge_draw(sheet_3d, ["x", "y"], ax, c='k')

# %%
from tyssue.draw.vispy_draw import vp_view
canvas, view = vp_view(sheet_3d)
_ = plt.imshow(canvas.render())
# Out:
# /home/guillaume/anaconda3/envs/py35/lib/python3.5/site-packages/IPython/config.py:13: ShimWarning: The `IPython.config` package has been deprecated. You should import from traitlets.config instead.
#   "You should import from traitlets.config instead.", ShimWarning)

# %% [markdown]
# ## Monolayer

# %%
from tyssue.core.monolayer import Monolayer
from tyssue.core.generation import extrude

extruded = extrude(sheet_3d.datasets, method='translation')
specs = config.geometry.bulk_spec()
monolayer = Monolayer('mono', extruded, specs)

# %%
canvas, view = vp_view(monolayer)
fig, ax = plt.subplots()
fig.set_size_inches(12, 12)
_ = ax.imshow(canvas.render())

# %% [markdown]
# ## Bulk tissue
